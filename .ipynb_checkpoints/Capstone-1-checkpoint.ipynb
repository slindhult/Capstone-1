# %% [markdown]
# https://www.kaggle.com/sogun3/uspollution
#
# The AQS Data Mart is a database containing all of the information from AQS. It has every measured value the EPA
# has collected via the national ambient air monitoring program. It also includes the associated aggregate values
# calculated by EPA (8-hour, daily, annual, etc.). The AQS Data Mart is a copy of AQS made once per week and made
# accessible to the public through web-based applications. The intended users of the Data Mart are air quality data
# analysts in the regulatory, academic, and health research communities. It is intended for those who need to
# download large volumes of detailed technical data stored at EPA and does not provide any interactive analytical
# tools. It serves as the back-end database for several Agency interactive tools that could not fully function
# without it: AirData, AirCompare, The Remote Sensing Information Gateway, the Map Monitoring Sites KML page, etc.
#
# AQS must maintain constant readiness to accept data and meet high data integrity requirements, thus is limited
# in the number of users and queries to which it can respond. The Data Mart, as a read only copy, can allow wider
# access.
#
# 47 states: District of Columbia, Country of Mexica
# Missing ['Mississippi', 'Montana', 'Nebraska', 'Vermont', 'West Virginia']
#
# Data was there, there were over about half the values were missing for the Air Quality Index for CO and SO2 but everythig else was there!  There were a few reading of negative values for the NO2 Mean, NO2 First Max Value, and SO2 Mean, SO2 First Max Value, CO Mean,
#
#
#
# The Clean Air Act requires EPA to set National Ambient Air Quality Standards (NAAQS)National Ambient Air Quality StandardsStandards established by EPA for maximum allowable concentrations of six "criteria" pollutants in outdoor air. This data set looks at four of the six pollutants are carbon monoxide, ground-level ozone, nitrogen dioxide, and sulfur dioxide. The standards are set at a level that protects public health with an adequate margin of safety. for six common air pollutants (also known as "criteria air pollutants"). These pollutants are found all over the U.S. They can harm your health and the environment, and cause property damage.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Reading in the data from https://www.kaggle.com/sogun3/uspollution
data = pd.read_csv('/home/slindhult/assignments/Capstone-1/Data/pollution_us_2000_2016.csv')

# %%
# Understanding the size of the dataframe
data.shape
# Out:
# (1746661, 29)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')

# %%
#Understanding the quality of the data by identifying null values
lst=[]

for col in data.columns:
    lst.append((col, data[col].isnull().sum()))
lst
# Out:
# [('Unnamed: 0', 0),
#  ('State Code', 0),
#  ('County Code', 0),
#  ('Site Num', 0),
#  ('Address', 0),
#  ('State', 0),
#  ('County', 0),
#  ('City', 0),
#  ('Date Local', 0),
#  ('NO2 Units', 0),
#  ('NO2 Mean', 0),
#  ('NO2 1st Max Value', 0),
#  ('NO2 1st Max Hour', 0),
#  ('NO2 AQI', 0),
#  ('O3 Units', 0),
#  ('O3 Mean', 0),
#  ('O3 1st Max Value', 0),
#  ('O3 1st Max Hour', 0),
#  ('O3 AQI', 0),
#  ('SO2 Units', 0),
#  ('SO2 Mean', 0),
#  ('SO2 1st Max Value', 0),
#  ('SO2 1st Max Hour', 0),
#  ('SO2 AQI', 872907),
#  ('CO Units', 0),
#  ('CO Mean', 0),
#  ('CO 1st Max Value', 0),
#  ('CO 1st Max Hour', 0),
#  ('CO AQI', 873323)]

# %%
#Understanding the quality of the data by identifying negative values and removing them
a = data.copy()
purged = a[(a[['NO2 Mean',
       'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 
       'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI',
       'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
       'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI']] >0).all(1)]

# %%
# Understanding what data is included - looks like some states are missing
states = data['State'].unique()
states_list = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
missing = [state for state in states_list if state not in states]
missing
# Out:
# ['Guam',
#  'Mississippi',
#  'Montana',
#  'Nebraska',
#  'Puerto Rico',
#  'Vermont',
#  'West Virginia']

# %%
purged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161180 entries, 1 to 1746506
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         161180 non-null  int64
#  1   State Code         161180 non-null  int64
#  2   County Code        161180 non-null  int64
#  3   Site Num           161180 non-null  int64
#  4   Address            161180 non-null  object
#  5   State              161180 non-null  object
#  6   County             161180 non-null  object
#  7   City               161180 non-null  object
#  8   Date Local         161180 non-null  object
#  9   NO2 Units          161180 non-null  object
#  10  NO2 Mean           161180 non-null  float64
#  11  NO2 1st Max Value  161180 non-null  float64
#  12  NO2 1st Max Hour   161180 non-null  int64
#  13  NO2 AQI            161180 non-null  int64
#  14  O3 Units           161180 non-null  object
#  15  O3 Mean            161180 non-null  float64
#  16  O3 1st Max Value   161180 non-null  float64
#  17  O3 1st Max Hour    161180 non-null  int64
#  18  O3 AQI             161180 non-null  int64
#  19  SO2 Units          161180 non-null  object
#  20  SO2 Mean           161180 non-null  float64
#  21  SO2 1st Max Value  161180 non-null  float64
#  22  SO2 1st Max Hour   161180 non-null  int64
#  23  SO2 AQI            161180 non-null  float64
#  24  CO Units           161180 non-null  object
#  25  CO Mean            161180 non-null  float64
#  26  CO 1st Max Value   161180 non-null  float64
#  27  CO 1st Max Hour    161180 non-null  int64
#  28  CO AQI             161180 non-null  float64
# dtypes: float64(10), int64(10), object(9)
# memory usage: 36.9+ MB

# %%
purged['month-day'] = purged['Date Local'].apply(lambda x: x[-5:])
# Out:
# /home/slindhult/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
purged['Date Local']=pd.to_datetime(purged['Date Local'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a1f60865e31> in <module>
# ----> 1 purged['Date Local']=pd.to_datetime(purged['Date Local'])
#
# NameError: name 'pd' is not defined

# %%
empty_list = []
for i in data.columns:
    empty_list.append((i, data[i].isnull().sum()))
empty_list
# Out:
# [('Unnamed: 0', 0),
#  ('State Code', 0),
#  ('County Code', 0),
#  ('Site Num', 0),
#  ('Address', 0),
#  ('State', 0),
#  ('County', 0),
#  ('City', 0),
#  ('Date Local', 0),
#  ('NO2 Units', 0),
#  ('NO2 Mean', 0),
#  ('NO2 1st Max Value', 0),
#  ('NO2 1st Max Hour', 0),
#  ('NO2 AQI', 0),
#  ('O3 Units', 0),
#  ('O3 Mean', 0),
#  ('O3 1st Max Value', 0),
#  ('O3 1st Max Hour', 0),
#  ('O3 AQI', 0),
#  ('SO2 Units', 0),
#  ('SO2 Mean', 0),
#  ('SO2 1st Max Value', 0),
#  ('SO2 1st Max Hour', 0),
#  ('SO2 AQI', 872907),
#  ('CO Units', 0),
#  ('CO Mean', 0),
#  ('CO 1st Max Value', 0),
#  ('CO 1st Max Hour', 0),
#  ('CO AQI', 873323)]

# %%
data.describe()
# Out:
#          Unnamed: 0    State Code   County Code      Site Num      NO2 Mean  \
# count  1.746661e+06  1.746661e+06  1.746661e+06  1.746661e+06  1.746661e+06
# mean   5.471414e+04  2.230907e+01  7.169381e+01  1.118214e+03  1.282193e+01
# std    3.372908e+04  1.725621e+01  7.948023e+01  2.003103e+03  9.504814e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+
# California                  10.449855   9.998355
# Colorado                    11.169307   8.749023
# Connecticut                 11.758091   5.137685
# Country Of Mexico           12.990335  20.408178
# Delaware                    12.812081   4.872483
# District Of Columbia        12.193977  13.613990
# Florida                     11.098370   7.047218
# Georgia                      9.156701   7.356701
# Hawaii                       9.152218   5.649194
# Idaho                       12.930435   3.460870
# Illinois                    12.061726   7.410460
# Indiana                     12.114996   6.728050
# Iowa                        12.741036   3.918991
# Kansas                      13.901865   8.144586
# Kentucky                    13.218989   4.749617
# Louisiana                   12.205855   8.413998
# Maine                       12.515337   4.419479
# Maryland                    11.307306   5.823288
# Massachusetts               15.223269   6.914272
# Michigan                    10.511754   7.156420
# Minnesota                   11.893204   4.276699
# Missouri                    13.144425   8.230465
# Nevada                      12.030195   7.150977
# New Hampshire               13.432473   5.993930
# New Jersey                  12.185781   7.872097
# New Mexico                  11.428571   4.973214
# New York                    13.390718   6.984438
# North Carolina              13.019372   7.280561
# North Dakota                12.355072   2.898551
# Ohio                        10.241174   4.833796
# Oklahoma                    13.557682   4.303030
# Oregon                      13.016181   6.689320
# Pennsylvania                11.537903   5.313719
# Rhode Island                10.750708   4.974504
# South Carolina               9.429630   2.170370
# South Dakota                11.508475   3.338983
# Tennessee                   10.376623   3.415584
# Texas                       12.536946   6.498461
# Utah                         9.556047   7.123894
# Virginia                    12.376821   6.656523
# Washington                  10.735294   3.073529
# Wisconsin                   13.847222   7.527778
# Wyoming                     11.594595   2.737452

# %%
day = purged[[
       'State', 'NO2 Mean',
       'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI',
       'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI',
       'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
        'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI','month-day']].copy()

# %%
#Mean pollutant state and day
day_state = day.groupby(['State','month-day']).agg({'NO2 Mean':'mean',
       'NO2 1st Max Value':'mean', 'NO2 1st Max Hour':'mean', 'NO2 AQI':'mean',
       'O3 Mean':'mean', 'O3 1st Max Value':'mean', 'O3 1st Max Hour':'mean', 'O3 AQI':'mean',
       'SO2 Mean':'mean', 'SO2 1st Max Value':'mean', 'SO2 1st Max Hour':'mean', 'SO2 AQI':'mean',
        'CO Mean':'mean', 'CO 1st Max Value':'mean', 'CO 1st Max Hour':'mean', 'CO AQI':'mean'})

# %%
byday = purged[[
       'month-day','NO2 Mean',
       'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI',
       'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI',
       'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
        'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI']].copy()

# %%
eachday = byday.groupby('month-day').agg({'NO2 Mean':'mean',
       'NO2 1st Max Value':'mean', 'NO2 1st Max Hour':'mean', 'NO2 AQI':'mean',
       'O3 Mean':'mean', 'O3 1st Max Value':'mean', 'O3 1st Max Hour':'mean', 'O3 AQI':'mean',
       'SO2 Mean':'mean', 'SO2 1st Max Value':'mean', 'SO2 1st Max Hour':'mean', 'SO2 AQI':'mean',
        'CO Mean':'mean', 'CO 1st Max Value':'mean', 'CO 1st Max Hour':'mean', 'CO AQI':'mean'})

# %%
eachday
# Out:
#             NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour    NO2 AQI  \
# month-day
# 01-01      16.479943          29.040392         13.888235  27.364706
# 01-02      21.954676          36.809443         15.113801  34.690073
# 01-03      22.784888          37.883296         14.494432  35.650334
# 01-04      23.468753          37.843665         14.452489  35.631222
# 01-05      24.046970          39.061072         14.508159  36.736597
# ...              ...                ...               ...        ...
# 12-27      21.732869          36.247938         15.172680  34.244845
# 12-28      22.954540          37.906699         14.904306  35.822967
# 12-29      22.527243          37.189488         14.369272  35.040431
# 12-30      22.558136          36.952368         14.481579  34.815789
# 12-31      21.150402          36.099057         14.297170  34.049528
#
#             O3 Mean  O3 1st Max Value  O3 1st Max Hour     O3 AQI  SO2 Mean  \
# month-day
# 01-01      0.017240          0.027027        10.994118  23.507843  2.482143
# 01-02      0.012679          0.023223        11.021792  20.174334  2.559597
# 01-03      0.012878          0.022784        10.360802  19.743875  2.695606
# 01-04      0.012047          0.022192        10.812217  19.282805  2.934895
# 01-05      0.012213          0.022207        10.720280  19.237762  2.894468
# ...             ...               ...              ...        ...       ...
# 12-27      0.012832          0.023034        10.231959  19.871134  2.468937
# 12-28      0.012670          0.022720        10.727273  19.528708  2.786956
# 12-29      0.011953          0.022590        11.277628  19.536388  2.707993
# 12-30      0.012192          0.021892        10.847368  18.876316  2.520053
# 12-31      0.014554          0.023113         9.757075  19.964623  2.441656
#
#            SO2 1st Max Value  SO2 1st Max Hour   SO2 AQI   CO Mean  \
# month-day
# 01-01               5.728824         10.362745  7.909804  0.546082
# 01-02               6.394431         11.338983  8.801453  0.658610
# 01-03               6.485969         11.316258  8.888641  0.698283
# 01-04               7.013575         11.278281  9.638009  0.706696
# 01-05               7.124942         11.566434  9.815851  0.729304
# ...                      ...               ...       ...       ...
# 12-27               6.412371         11.922680  8.814433  0.643056
# 12-28               6.857656         11.617225  9.294258  0.709795
# 12-29               6.518329         11.657682  8.986523  0.696522
# 12-30               6.472632         11.655263  8.886842  0.686051
# 12-31               5.993396         12.181604  8.202830  0.652965
#
#            CO 1st Max Value  CO 1st Max Hour     CO AQI
# month-day
# 01-01              0.866078        11.105882   9.854902
# 01-02              1.011380        13.612591  11.532688
# 01-03              1.104900        13.728285  12.590200
# 01-04              1.076923        11.959276  12.282805
# 01-05              1.119347        13.358974  12.766900
# ...                     ...              ...        ...
# 12-27              0.995876        12.997423  11.360825
# 12-28              1.088038        12.566986  12.366029
# 12-29              1.078437        13.018868  12.307278
# 12-30              1.058158        12.971053  12.073684
# 12-31              1.048349        13.221698  11.933962
#
# [366 rows x 16 columns]

# %%
cols = eachday.columns

# %%
fig, axs = plt.subplots(4,4,figsize=(10,10))

axs=axs.flatten()
for i, col in enumerate(cols):   
    axs[i].plot(eachday.index,eachday[col])
    axs[i].set_title(col)
fig.tight_layout()

# %%
purged['year'] = purged['Date Local'].apply(lambda x: x[:4])
# Out:
# /home/slindhult/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
purged.head()
# Out:
#     Unnamed: 0  State Code  County Code  Site Num  \
# 1            1           4           13      3002
# 9            9           4           13      3002
# 13          13           4           13      3002
# 17          17           4           13      3002
# 21          21           4           13      3002
#
#                                     Address    State    County     City  \
# 1   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 9   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 13  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 17  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 21  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#     Date Local          NO2 Units  ...  SO2 1st Max Value  SO2 1st Max Hour  \
# 1   2000-01-01  Parts per billion  ...                9.0                21
# 9   2000-01-03  Parts per billion  ...               11.0                19
# 13  2000-01-04  Parts per billion  ...               16.0                 8
# 17  2000-01-05  Parts per billion  ...               15.0                 7
# 21  2000-01-06  Parts per billion  ...               17.0                 7
#
#     SO2 AQI           CO Units   CO Mean  CO 1st Max Value  CO 1st Max Hour  \
# 1      13.0  Parts per million  0.878947               2.2               23
# 9      16.0  Parts per million  1.762500               2.5                8
# 13     23.0  Parts per million  1.829167               3.0               23
# 17     21.0  Parts per million  2.700000               3.7                2
# 21     24.0  Parts per million  2.308333               3.6                9
#
#     CO AQI  month-day  year
# 1     25.0      01-01  2000
# 9     28.0      01-03  2000
# 13    34.0      01-04  2000
# 17    42.0      01-05  2000
# 21    41.0      01-06  2000
#
# [5 rows x 31 columns]

# %%
year = purged[[
         'NO2 Mean', 'NO2 AQI',
       'O3 Mean','O3 AQI',
       'SO2 Mean','SO2 AQI',
        'CO Mean','CO AQI', 'year']].copy()

# %%
# Mean pollutants
y = year.groupby('year').agg({'NO2 Mean':'mean',
       'NO2 AQI':'mean',
       'O3 Mean':'mean', 'O3 AQI':'mean',
       'SO2 Mean':'mean', 'SO2 AQI':'mean',
        'CO Mean':'mean', 'CO AQI':'mean'})

# %%
# Out:
#        NO2 Mean    NO2 AQI    O3 Mean     O3 AQI  SO2 Mean    SO2 AQI  \
# year
# 2000  20.810474  36.496388  22.463581  35.553825  4.183604  16.639544
# 2001  21.252550  37.323324  23.600264  38.044683  3.665755  15.160322
# 2002  20.498792  36.113330  24.638934  39.425291  3.348621  13.759561
# 2003  19.610476  34.496738  23.618947  37.560143  3.408764  13.629766
# 2004  18.421408  32.654405  23.268730  35.681725  3.430012  13.658815
# 2005  18.496737  33.202029  24.046397  37.890516  3.385338  13.227544
# 2006  18.088789  32.954667  23.842027  36.362482  3.051909  12.123659
# 2007  17.000199  31.389606  24.566783  37.273939  2.818748  11.197671
# 2008  16.129939  30.419237  24.548507  37.018096  2.361090   9.532894
# 2009  15.959747  29.524654  23.443004  33.987729  2.101053   7.776328
# 2010  16.078676  29.977803  24.353775  35.897140  1.744444   6.296110
# 2011  15.985758  29.161127  23.712912  34.608479  1.826792   6.715466
# 2012  15.800807  29.221507  24.417439  36.375068  1.535036   6.005998
# 2013  15.829178  28.753152  23.559002  35.945157  1.338868   5.174119
# 2014  15.342397  28.695083  23.702276  37.589264  1.387485   5.425916
# 2015  14.683201  27.581663  23.381712  37.506137  1.275270   4.963176
# 2016  15.895468  30.156538  21.950382  32.529159  1.173935   4.448128
#
#          CO Mean     CO AQI
# year
# 2000  656.365691  11.488208
# 2001  606.796685  10.711886
# 2002  599.028225  10.519873
# 2003  587.352504  10.055046
# 2004  530.295831   8.978810
# 2005  494.566951   8.382830
# 2006  501.209617   8.723176
# 2007  458.925178   7.752468
# 2008  409.163138   7.023801
# 2009  412.745018   7.046631
# 2010  411.866818   6.961899
# 2011  395.284657   6.686604
# 2012  381.609276   6.452176
# 2013  366.403443   6.236397
# 2014  357.449280   6.086899
# 2015  363.064153   6.225326
# 2016  380.010438   6.578269

# %%
fig, ax = plt.subplots(figsize=(15,5))


  
ax.plot(y.index,y['NO2 Mean'], label='NO2')
ax.plot(y.index,y['SO2 Mean'], label='SO2')
ax.set_title('Pollutants in PPB by Year')
ax.set_xlabel('Year')
ax.set_ylabel('PPB')
ax.legend();

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(15,5))

ax.plot(y.index,y['O3 Mean'], label='O3')
ax.plot(y.index,y['CO Mean'], label='CO')
ax.set_xlabel('Year')
ax.set_ylabel('PPM')
ax.set_title('Pollutants in PPM by Year')

ax.legend();

# %%
fig, axs = plt.subplots(2,4,figsize=(15,5))

axs.flatter()
  
axs[0].plot(y.index,y['NO2 Mean'], label='NO2')
axs[1].plot(y.index,y['SO2 Mean'], label='SO2')
ax.set_title('Pollutants in PPB by Year')
ax.set_xlabel('Year')
ax.set_ylabel('PPB')
ax.legend();
